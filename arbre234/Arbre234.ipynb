# %%
from Arbre234 import Arbre234

# %% [markdown]
# # Arbre 234

# %%
A = Arbre234()
A = A.ajout(8)
A = A.ajout(3)
A = A.ajout(2)
A = A.ajout(4)
A = A.ajout(1)
A = A.ajout(15)
A = A.ajout(10)
A = A.ajout(9)


A = A.ajout(11)
A = A.ajout(7)
A = A.ajout(6)
A = A.ajout(13)
A = A.ajout(12)
A = A.ajout(5)
A = A.ajout(14)
A = A.ajout(16)
A = A.ajout(17)

A.visualiser_arbre()

# %%
A = A.supprime(6)
A = A.supprime(5)
A = A.supprime(3)
A = A.supprime(2)
A = A.supprime(9)
A = A.supprime(11)
A = A.supprime(13)
A = A.supprime(15)
A = A.supprime(12)
# A = A.supprime(14)

A.visualiser_arbre()

# %%
A = A.supprime(4)

A.visualiser_arbre()

# %% [markdown]
# ## Test avec un grand arbre

# %%
B = Arbre234()
B = B.construction([8, 3, 2, 4, 1, 15, 10, 9, 11, 7, 6, 13, 12, 5, 14, 16, 17, 25, 30, 22, 23, 24, 26, 27, 28, 29, 18, 19, 20, 21])
B = B.supprime(6)
B = B.supprime(3)
B = B.supprime(11)
B = B.supprime(2)
B = B.supprime(4)

B = B.supprime(10)
B = B.supprime(9)
B = B.supprime(7)
B = B.supprime(8)
B = B.supprime(5)
B = B.supprime(21)
B = B.supprime(30)

B.visualiser_arbre()

# %%
B = B.supprime(24)

B.visualiser_arbre()

# %%
def papa(A):
    if A._pere() is not None:
        print(A._contenu(), A._pere()._contenu())
    if not A._est_feuille():
        for (i, a) in enumerate(A._sous_arbres()):
            papa(a)

papa(B)
# Out:
# [12] [14, 18, 26]
# [1] [12]
# [13] [12]
# [16] [14, 18, 26]
# [15] [16]
# [17] [16]
# [20, 23] [14, 18, 26]
# [19] [20, 23]
# [22] [20, 23]
# [25] [20, 23]
# [28] [14, 18, 26]
# [27] [28]
# [29] [28]
