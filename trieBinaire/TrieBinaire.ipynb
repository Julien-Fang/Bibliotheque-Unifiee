# %%
from TrieBinaire import TrieBinaire

# %% [markdown]
# # Trie Binaire

# %%
def test_TrieBin():
    dico = {'A': '00001', 'S': '10011', 'E': '00101', 'R': '10010', 'C': '00011', 'H': '01000', 'I': '01001', 'N': '01110', 'G': '00111', 'X': '11000', 'M': '01101', 'P': '10000', 'L': '01100'}
    triebin = TrieBinaire(dico)
    triebin = triebin.construction()
    triebin.afficher_arbre(triebin.racine)

test_TrieBin()
# Out:
#    |--X
# |--*
#    |--*
#             |--S
#          |--*
#             |--R
#       |--*
#          |--P
# *
#          |--N
#       |--*
#             |--M
#          |--*
#             |--L
#    |--*
#       |--*
#             |--I
#          |--*
#             |--H
# |--*
#          |--G
#       |--*
#          |--E
#    |--*
#          |--C
#       |--*
#          |--A

# %% [markdown]
# <h1>TEST</h1>

# %% [markdown]
# <h2>Test Ajout</h2>

# %%
dico = {'A': '00001', 'S': '10011', 'E': '00101', 'R': '10010', 'C': '00011', 'H': '01000', 'I': '01001', 'N': '01110', 'G': '00111', 'X': '11000', 'M': '01101', 'P': '10000', 'L': '01100'}

# %%
test_TrieBin = TrieBinaire(dico)
test_TrieBin.racine = test_TrieBin.ajout('A')
test_TrieBin.racine = test_TrieBin.ajout('S')
test_TrieBin.visualiser_arbre()

# %%
test_TrieBin.racine = test_TrieBin.ajout('I')
test_TrieBin.racine = test_TrieBin.ajout('X')
test_TrieBin.visualiser_arbre()

# %%
test_TrieBin.racine = test_TrieBin.ajout('E')
test_TrieBin.racine = test_TrieBin.ajout('R')
test_TrieBin.visualiser_arbre()

# %% [markdown]
# <h2>Tester Construction</h2>

# %%
test_TrieBin2 = TrieBinaire(dico)
test_TrieBin2 = test_TrieBin2.construction()
test_TrieBin2.visualiser_arbre()

# %%
test_TrieBin2.racine = test_TrieBin2.suppression('R')
test_TrieBin2.racine = test_TrieBin2.suppression('S')
test_TrieBin2.racine = test_TrieBin2.suppression('P')
test_TrieBin2.visualiser_arbre()

# %%
test_TrieBin2.racine = test_TrieBin2.suppression('A')
test_TrieBin2.visualiser_arbre()

# %%
test_TrieBin2.racine = test_TrieBin2.suppression('C')
test_TrieBin2.visualiser_arbre()

# %%
test_TrieBin2.racine = test_TrieBin2.suppression('G')
test_TrieBin2.visualiser_arbre()

# %% [markdown]
# <h2>TEST 2</h2>

# %%
dico2 = {'A': '10001', 'S': '10010', 'R': '10100',  'H': '10101', 'G': '11000', 'M': '11010', 'L': '11111'}

# %%
test_TrieBin3 = TrieBinaire(dico2)
test_TrieBin3 = test_TrieBin3.construction()

print("recherche du mot 'A' : ", test_TrieBin3.recherche('A'))
print("recherche du mot 'Z' : ", test_TrieBin3.recherche('Z'))

test_TrieBin3.visualiser_arbre()
# Out:
# recherche du mot 'A' :  True
# recherche du mot 'Z' :  False

# %%
test_TrieBin4 = TrieBinaire(dico2)
test_TrieBin4.racine = test_TrieBin4.ajout('A')
test_TrieBin4.racine = test_TrieBin4.ajout('S')
test_TrieBin4.visualiser_arbre()

# %%
test_TrieBin4.racine = test_TrieBin4.suppression('A')
test_TrieBin4.visualiser_arbre()

# %%
test_TrieBin4.racine = test_TrieBin4.suppression('S')
test_TrieBin4.visualiser_arbre()
