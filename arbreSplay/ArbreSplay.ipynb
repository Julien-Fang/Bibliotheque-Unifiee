# %%
from ArbreSplay import ArbreSplay

# %% [markdown]
# # SPLAY TREE

# %%
# Create an instance of ArbreSplay
splay_tree = ArbreSplay()

# ajout noeuds into the Splay tree
splay_tree = splay_tree.ajout_liste([3,5,4,7,6])
dot = splay_tree.visualiser_arbre()
dot

# %% [markdown]
# #### Ajout par étape

# %%
# Create an instance of ArbreSplay
splay_tree = ArbreSplay()

# ajout noeuds into the Splay tree
splay_tree = splay_tree.ajout(3)
dot = splay_tree.visualiser_arbre()
dot

# %%
# ajout noeuds into the Splay tree
splay_tree = splay_tree.ajout(5)
dot = splay_tree.visualiser_arbre()
dot

# %%
# ajout noeuds into the Splay tree
splay_tree = splay_tree.ajout(4)
dot = splay_tree.visualiser_arbre()
dot

# %%
# ajout noeuds into the Splay tree
splay_tree = splay_tree.ajout(7)
dot = splay_tree.visualiser_arbre()
dot

# %%
# ajout noeuds into the Splay tree
splay_tree = splay_tree.ajout(6)
dot = splay_tree.visualiser_arbre()
dot

# %% [markdown]
# #### Suppression :

# %%
# Create an instance of ArbreSplay
splay_tree = ArbreSplay()

# ajout noeuds into the Splay tree
splay_tree = splay_tree.ajout_liste([3,5,4,7,6])
splay_tree = splay_tree.supprime(4)
dot = splay_tree.visualiser_arbre()
dot

# %% [markdown]
# #### Recherche

# %%
# Create an instance of ArbreSplay
splay_tree = ArbreSplay()

# ajout noeuds into the Splay tree
splay_tree = splay_tree.ajout_liste([3,5,4,7,6])

cleExist,splay_tree_modif = splay_tree.recherche(7)
print(cleExist)
dot = splay_tree.visualiser_arbre() # non modifié 
dot
# Out:
# True

# %%
dot = splay_tree_modif.visualiser_arbre() # modifié 
dot

# %%
splay_tree_modif2 = splay_tree_modif.ajout(50)
dot = splay_tree_modif.visualiser_arbre()
dot

# %%
dot = splay_tree_modif2.visualiser_arbre()
dot

# %%
splay_tree_modif3 = splay_tree_modif2.supprime(7)
dot = splay_tree_modif2.visualiser_arbre() # non modifié
dot

# %%
dot = splay_tree_modif3.visualiser_arbre() # modifié 
dot
