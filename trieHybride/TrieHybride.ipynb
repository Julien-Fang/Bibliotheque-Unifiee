# %%
from TrieHybride import TrieHybride

# %% [markdown]
# # Trie Hybride

# %%
def afficher_trie_hybride_arbre(A, prefixe="", est_dernier=True, lien=""):
    if A is not None:
        marker = "└── " if est_dernier else "├── "
        print(f"{prefixe}{marker}Caractère: {A.c} ({lien})", "Valeur: ", A.v if A.v is not None else "None")
        afficher_trie_hybride_arbre(A.inf, f"{prefixe}{'    ' if est_dernier else '│   '}", False, "Inf")
        afficher_trie_hybride_arbre(A.eq, f"{prefixe}{'    ' if est_dernier else '│   '}", False, "Eq")
        afficher_trie_hybride_arbre(A.sup, f"{prefixe}{'    ' if est_dernier else '│   '}", True, "Sup")

# %%
trie_hybride = TrieHybride()

trie_hybride.racine = trie_hybride.ajout("chat", trie_hybride.racine, 1)
afficher_trie_hybride_arbre(trie_hybride.racine)
print("--------------------------------------------------")

trie_hybride.racine = trie_hybride.ajout("chien", trie_hybride.racine, 2)
afficher_trie_hybride_arbre(trie_hybride.racine)
print("--------------------------------------------------")

trie_hybride.racine = trie_hybride.ajout("cheval", trie_hybride.racine, 3)
afficher_trie_hybride_arbre(trie_hybride.racine)
print("--------------------------------------------------")

trie_hybride.racine = trie_hybride.ajout("bonjour", trie_hybride.racine, 4)
afficher_trie_hybride_arbre(trie_hybride.racine)
print("--------------------------------------------------")

trie_hybride.racine = trie_hybride.ajout("bien", trie_hybride.racine, 5)
afficher_trie_hybride_arbre(trie_hybride.racine)
print("--------------------------------------------------")

trie_hybride.racine = trie_hybride.ajout("merci", trie_hybride.racine, 6)
afficher_trie_hybride_arbre(trie_hybride.racine)
print("--------------------------------------------------")

trouver = trie_hybride.recherche("chat", trie_hybride.racine)
print(trouver)

trouver = trie_hybride.recherche("meow", trie_hybride.racine)
print(trouver)

trouver = trie_hybride.recherche("chien", trie_hybride.racine)
print(trouver)

trouver = trie_hybride.recherche("vache", trie_hybride.racine)
print(trouver)
# Out:
# └── Caractère: c () Valeur:  None
#     ├── Caractère: h (Eq) Valeur:  None
#     │   ├── Caractère: a (Eq) Valeur:  None
#     │   │   ├── Caractère: t (Eq) Valeur:  1
# --------------------------------------------------
# └── Caractère: c () Valeur:  None
#     ├── Caractère: h (Eq) Valeur:  None
#     │   ├── Caractère: a (Eq) Valeur:  None
#     │   │   ├── Caractère: t (Eq) Valeur:  1
#     │   │   └── Caractère: i (Sup) Valeur:  None
#     │   │       ├── Caractère: e (Eq) Valeur:  None
#     │   │       │   ├── Caractère: n (Eq) Valeur:  2
# --------------------------------------------------
# └── Caractère: c () Valeur:  None
#     ├── Caractère: h (Eq) Valeur:  None
#     │   ├── Caractère: a (Eq) Valeur:  None
#     │   │   ├── Caractère: t (Eq) Valeur:  1
#     │   │   └── Caractère: i (Sup) Valeur:  None
#     │   │       ├── Caractère: e (Inf) Valeur:  None
#     │   │       │   ├── Caractère: v (Eq) Valeur:  None
# ...

# %%
trie_hybride.visualiser_arbre()

# %%
trie_hybride.racine = trie_hybride.suppression("chat", trie_hybride.racine)
trie_hybride.visualiser_arbre()

# %%
trie_hybride.racine = trie_hybride.ajout("chaton", trie_hybride.racine, 7)
trie_hybride.visualiser_arbre()

# %%
TrieTest = TrieHybride()
TrieTest.racine = TrieTest.ajout("chiot", TrieTest.racine, 1)
TrieTest.racine = TrieTest.ajout("chat", TrieTest.racine, 2)
TrieTest.racine = TrieTest.ajout("chut", TrieTest.racine, 3)
TrieTest.visualiser_arbre()

# %%
TrieTest.racine = TrieTest.suppression("chiot", TrieTest.racine)
TrieTest.visualiser_arbre()

# %%
TrieTest2 = TrieHybride()
TrieTest2.racine = TrieTest2.ajout("chu", TrieTest2.racine, 1)
TrieTest2.racine = TrieTest2.ajout("chiot", TrieTest2.racine, 2)
TrieTest2.racine = TrieTest2.ajout("chat", TrieTest2.racine, 3)
TrieTest2.racine = TrieTest2.ajout("chut", TrieTest2.racine, 4)
TrieTest2.visualiser_arbre()

# %%
TrieTest2.racine = TrieTest2.suppression("chu", TrieTest2.racine)
TrieTest2.visualiser_arbre()

# %%
TrieTest3 = TrieHybride()
TrieTest3.racine = TrieTest3.ajout("chiot", TrieTest3.racine, 1)
TrieTest3.racine = TrieTest3.ajout("chat", TrieTest3.racine, 2)
TrieTest3.racine = TrieTest3.ajout("chut", TrieTest3.racine, 3)

TrieTest3.racine = TrieTest3.suppression("chat", TrieTest3.racine)
TrieTest3.visualiser_arbre()

# %%
TrieTest4 = TrieHybride()
TrieTest4.racine = TrieTest4.ajout("chiot", TrieTest4.racine, 1)
TrieTest4.racine = TrieTest4.ajout("chat", TrieTest4.racine, 2)
TrieTest4.racine = TrieTest4.ajout("chut", TrieTest4.racine, 3)

TrieTest4.racine = TrieTest4.suppression("chut", TrieTest4.racine)
TrieTest4.visualiser_arbre()

# %%
TrieTest5 = TrieHybride()
TrieTest5.racine = TrieTest5.ajout("chiot", TrieTest5.racine, 1)
TrieTest5.racine = TrieTest5.ajout("chat", TrieTest5.racine, 2)
TrieTest5.racine = TrieTest5.ajout("chut", TrieTest5.racine, 3)
TrieTest5.racine = TrieTest5.ajout("chien", TrieTest5.racine, 4)
TrieTest5.racine = TrieTest5.ajout("chats", TrieTest5.racine, 5)

TrieTest5.visualiser_arbre()

# %%
TrieTest5.racine = TrieTest5.suppression("chat", TrieTest5.racine)
TrieTest5.visualiser_arbre()

# %%
TrieTest5.racine = TrieTest5.suppression("chats", TrieTest5.racine)
TrieTest5.racine = TrieTest5.suppression("chiot", TrieTest5.racine)
TrieTest5.racine = TrieTest5.suppression("chien", TrieTest5.racine)

TrieTest5.racine = TrieTest5.ajout("chute", TrieTest5.racine, 6)
TrieTest5.racine = TrieTest5.ajout("chu", TrieTest5.racine, 7)
 
TrieTest5.visualiser_arbre()

# %%
TrieTest5.racine = TrieTest5.suppression("chu", TrieTest5.racine)

TrieTest5.visualiser_arbre()
