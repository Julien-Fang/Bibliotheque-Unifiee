# %%
from TasMin import TasMin

# %% [markdown]
# # Tas Min

# %%
#exemple du cours
min_tas = TasMin()
min_tas = min_tas.ajout_liste([2 , 6 , 5 , 10 , 13 , 7 , 8 , 12 , 15 , 14])
print(len(min_tas.tas))
print(min_tas._est_tas())
dot = min_tas.visualiser_arbre()
dot
# Out:
# 10
# True

# %%
A = min_tas.ajout(4)
print(A.tas)
print(min_tas.tas)
dot = A.visualiser_arbre() # modifie
dot
# Out:
# [2, 4, 5, 10, 6, 7, 8, 12, 15, 14, 13]
# [2, 6, 5, 10, 13, 7, 8, 12, 15, 14]

# %%
dot = min_tas.visualiser_arbre() # non modifié
dot

# %%
#exemple du cours
min_tas = TasMin()
min_tas = min_tas.ajout_liste([2 , 6 , 5 , 10 , 13 , 7 , 8 , 12 , 15 , 14])
min, A = min_tas.extractMin()
print(min)
print(A.tas)
print(min_tas.tas)
dot = A.visualiser_arbre() # modifié
dot
# Out:
# 2
# [5, 6, 7, 10, 13, 14, 8, 12, 15]
# [2, 6, 5, 10, 13, 7, 8, 12, 15, 14]

# %%
dot = min_tas.visualiser_arbre() # non modifié
dot
