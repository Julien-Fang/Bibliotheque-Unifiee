# %%
from ArbreAVL import ArbreAVL

# %% [markdown]
# # ARBRE AVL

# %% [markdown]
# #### Ajout et visualisation par étape

# %%
# Create an instance of ArbreAVL
avl_tree = ArbreAVL()

# ajout nodes into the AVL tree
avl_tree = avl_tree.ajout(10)
dot = avl_tree.visualiser_arbre()
dot

# %%
avl_tree = avl_tree.ajout(20)
dot = avl_tree.visualiser_arbre()
dot

# %%
avl_tree = avl_tree.ajout(30)
dot = avl_tree.visualiser_arbre()
dot

# %%
avl_tree = avl_tree.ajout(40)
dot = avl_tree.visualiser_arbre()
dot

# %%
avl_tree = avl_tree.ajout(50)
dot = avl_tree.visualiser_arbre()
dot

# %%
avl_tree = avl_tree.supprime(10)
dot = avl_tree.visualiser_arbre()
dot

# %% [markdown]
# #### Ajout par liste

# %%
# Create an instance of ArbreAVL
avl_tree = ArbreAVL()

# ajout nodes into the AVL tree
avl_tree = avl_tree.ajout_liste([10, 20, 30, 40, 50])
# avl_tree.ajout(10)
# avl_tree.ajout(20)
# avl_tree.ajout(30)
# avl_tree.ajout(40)
# avl_tree.ajout(50)

# # Visualize the AVL tree
dot = avl_tree.visualiser_arbre()
dot
# dot.render('avl_tree_example', format='png', view=True)

# %%
# ajouter un noeud à l'arbre A
A = avl_tree.ajout(60)
dot = A.visualiser_arbre()
dot

# %%
# non modifie 
dot = avl_tree.visualiser_arbre()
dot

# %%
#on supprime 40 et on visualise l'arbre A qui est modifié
A = avl_tree.supprime(40)
dot = A.visualiser_arbre()
dot

# %%
dot = avl_tree.visualiser_arbre()  # on visualise l'arbre qui n'a pas été modifié
dot

# %% [markdown]
# #### Ajout avec double rotation

# %%
# Create an instance of ArbreAVL
avl_tree = ArbreAVL()

# ajout nodes into the AVL tree
avl_tree = avl_tree.ajout(13)
avl_tree = avl_tree.ajout(10)
avl_tree = avl_tree.ajout(15)
avl_tree = avl_tree.ajout(5)
avl_tree = avl_tree.ajout(11)
avl_tree = avl_tree.ajout(16)
avl_tree = avl_tree.ajout(4)
avl_tree = avl_tree.ajout(8)
dot = avl_tree.visualiser_arbre()
dot

# %%
avl_tree = avl_tree.ajout(3)
dot = avl_tree.visualiser_arbre()
dot

# %% [markdown]
# #### Suppression avec double rotation

# %%
# Create an instance of ArbreAVL
avl_tree = ArbreAVL()

# ajout nodes into the AVL tree
avl_tree = avl_tree.ajout(50)
avl_tree = avl_tree.ajout(40)
avl_tree = avl_tree.ajout(60)
avl_tree = avl_tree.ajout(30)
avl_tree = avl_tree.ajout(45)
avl_tree = avl_tree.ajout(55)
avl_tree = avl_tree.ajout(10)
dot = avl_tree.visualiser_arbre()
dot

# %%
avl_tree = avl_tree.supprime(60)
dot = avl_tree.visualiser_arbre()
dot

# %% [markdown]
# #### Suppression sans enfant pour remplacer

# %%
avl_tree = ArbreAVL()


# ajout nodes into the AVL tree
avl_tree = avl_tree.ajout(10)
avl_tree = avl_tree.ajout(20)
avl_tree = avl_tree.ajout(30)
avl_tree = avl_tree.ajout(40)
avl_tree = avl_tree.ajout(50)
dot = avl_tree.visualiser_arbre()
dot

# %%
avl_tree.racine = avl_tree._supprime(avl_tree.racine,10)
dot = avl_tree.visualiser_arbre()
dot

# %% [markdown]
# ## Recherche :
# ##### retourne un booléen et l'arbre

# %%
print(A.recherche(30))  # Output: True
print(A.recherche(40))  # Output: False
# Out:
# (True, <ArbreAVL.ArbreBinaire object at 0x000001B617A58E90>)
# (False, None)

# %%
print(avl_tree.recherche(30))  # Output: True
print(avl_tree.recherche(40))  # Output: True
# Out:
# (True, <ArbreAVL.ArbreBinaire object at 0x000001B617A4D710>)
# (True, <ArbreAVL.ArbreBinaire object at 0x000001B617A4D990>)
