# %%
from FileBinomiale import FileBinomiale

# %% [markdown]
# # File Binomiale

# %%
# Create an instance of FileBinomiale
file = FileBinomiale()

# Add the arbre to the file_binomiale
file = file.ajout_liste([173,20,92,124,100,6,79,75,67]) #

dot = file.visualiser_arbre()
dot

# %%
A = file.ajout(60) # Ajout de 60 dans A, file n'est pas modifié
dot = file.visualiser_arbre()
dot

# %%
dot = A.visualiser_arbre() # A est modifié
dot

# %%
e,B = A.extractMin() # Extraction du minimum de A = 6
dot = A.visualiser_arbre() # A n'est pas modifié
dot

# %%
print(e)
dot = B.visualiser_arbre() # B est modifié
dot
# Out:
# 6

# %%
e,C = B.extractMin() # Extraction du minimum de A = 6
print(e)
dot = C.visualiser_arbre() # A n'est pas modifié
dot
# Out:
# 20
