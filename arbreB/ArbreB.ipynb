# %%
from ArbreB import ArbreB
from random import randint

# %% [markdown]
# # Arbres-B
#
# Pour un arbre d'ordre m:
# - Noeuds : m <= k <= 2m clés
# - Racine : 1 <= k <= 2m clés

# %% [markdown]
# # Table des matières <a class="anchor" id="menu"></a>
# * [Graphviz](#graphviz)
# * [Arbre-B et PageB](#btree)
# * [Tests](#tests)
# <!-- * [Arbre-B et PageB V2](#btree2) -->

# %%
btree = ArbreB(2)
for i in range(22):
    # i = randint(0,80)
    # print("ajout de cle ",i)
    btree.ajout(i)

# if btree.recherche(16):
#     print("j'ai trouve !")
# else:
#     print("recherche echouee ?")

dot = btree.visualiser_arbre()
dot
# print(dot.source)

# %%
duplique = btree._duplique()
dot2 = duplique.visualiser_arbre()
dot2

# %%
duplique.suppression(8)
dot0 = duplique.visualiser_arbre()
dot0

# %%
dot = btree.visualiser_arbre()
dot

# %%
btree3 = ArbreB(2)
for i in range(30):
    # k = randint(1,20)
    # print("ajout de cle ",k)
    btree3.ajout(i)
dot3 = btree3.visualiser_arbre()
dot3

# %%
btree3.suppression(11)
dot4 = btree3.visualiser_arbre()
dot4

# %%
btree3.suppression(15)
btree3.suppression(14)
btree3.suppression(17)
btree3.suppression(20)
btree3.suppression(12)
btree3.suppression(10)
btree3.suppression(9)
btree3.suppression(5)
btree3.suppression(6)
dot5 = btree3.visualiser_arbre()
dot5

# %%
# btree3.ajout(8)
btree3.suppression(19)
dot6 = btree3.visualiser_arbre()
dot6

# %%
btree4 = ArbreB(2)
for i in range(100):
    i = randint(1,150)
    btree4.ajout(i)
dot7 = btree4.visualiser_arbre()
dot7

# %%
for i in range(50):
    i = randint(1,150)
    btree4.suppression(i)
dot8 = btree4.visualiser_arbre()
dot8
