# %%
from Abr import ABR

# %% [markdown]
# # Arbre Binaire de Recherche

# %% [markdown]
# # Test d'ajout

# %%
abr = ABR()
abr = abr.ajout_liste([5, 3, 8, 2, 4, 6, 9])

dot = abr.visualiser_arbre()
dot

# %% [markdown]
# # Test de suppression

# %%
A = abr.supprime(3)
dot = A.visualiser_arbre()
dot

# %% [markdown]
# # Test de recherche

# %%
dot = abr.visualiser_arbre()
dot

# %%
print(abr.recherche(6))
print(abr.recherche(10))
# Out:
# True
# False
